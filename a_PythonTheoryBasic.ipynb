# %% [markdown]
# # Python

# %%
# Python (One example of code procedure + Add more later)
	# 1. Python Basic:
		# 1. Python programming language (Terminal, Console, IDE, Venv, Pseudocode, Use case, Flowchart, Programming language, compiler, interpreter)
		# 2. Python Principles (DRY, KISS, YAGNI, SOLID, PEP)
		# 3. Variable, Data Types (int, float, string, bool, complex), Casting, Positive & Negative Slicing
		# 4. Operators (Assignment, Arithmetic, Comparison, Logical, Membership, Bitwise), Dynamic & Static Allocation
		# 5. Data Stucture / Data Collection (List, Tuple, Dictionary, Sets)
		# 6. Conditional (if, if...else, if...elif...else, nested if) & Iterative (while, for) & Transfer statements (break, continue, pass)
		# 7. Functions & Parameters & High Order Function (map(), filter(), reduce(), lambda()) & Iterator & Decorator & Generator
		# 8. OOP Principles (class, object, methods, atributes, constructor, self, Inheritance, Encapsulation, Abstractization, Polymorfism) & Exception Handling

# %% [markdown]
# # 0. Python (Terminal, Console, IDE, Venv, Pseudocode, Use case, Flowchart, Programming language, compiler, interpreter)
#
# # 1. Python programming language
#
# # 2. Python Principles (DRY, KISS, YAGNI, SOLID, PEP)

# %%
# 0. Python (Terminal, Console, IDE, Venv, Pseudocode, Use case, Flowchart, Programming language, compiler, interpreter)
		# Terminal = allows to enter commands that computer processes
		# Console = view the output and examine running variables
		# IDE = Integrated Development Environment = Code editor
			# Visual Studio Code (Web Development), PyCharm (Scripting), Jupyter/Google Colab (Data Science), Spyder (Data Science)
		# Venv = Virtual Environment = to manage Python packages and libraries for different projects
		# Pseudocode = method of planning, which enables the programmer to plan without syntax. can't be compiled or interpreted by the computer.
		# Use case = methodology used in system analysis to identify, clarify and organize system requirements. defines a list of steps that illustrate how a process will be carried out in a system.
		# Flowchart = shows the flow of data in a process. provides a representation of the algorithm detailing the steps more clearly, flow charts are easy to understand

		# 1. Programming language = bridge between human language and machine language
		# 2. Language translator
		  # 1. compiler = executes the complete code at once. (C, C++)
		  # 2. interpreter = executes the code line by line (Python)

		# Machine language = binary code = combination of 0 and 1
		  # 1. 1 bit = memory with one value
		  # 2. 1 byte = 8 bits
		  # 3. 1 kilobyte = 1024 bytes
		  # 4. 1 megabyte = 1024 kilobytes

# %%
# 1. Python programming language
	# created by Guido van Rossum, and released in 1991
	# one of the most accessible and popular programming languages
	# works on different platforms (Windows, Mac, Linux)
	# has a simple syntax and it is easy to code
	# runs on an interpreter system, meaning that the computer program converts high-level language into machine code (low level language) and executes the command line by line that you write into code that the computer can understand
	# the code can be easily written and executed much faster than other programming languages
	# object oriented programming language

	# can
		# be used on a server to create web applications.
		# be used alongside software to create workflows.
		# connect to database systems. It can also read and modify files.
		# be used to handle big data and perform complex mathematics.
		# be used for rapid prototyping, or for production-ready software development.
	# used for
		# web development (server-side) (Django, Flask)
		# software development
		# data science (data analysis, and data visualization) (NumPy, Pandas, Matplotlib, Seaborn)
		# machine learning (TensorFlow, PyTorch, Scikit-learn)
		# artificial inteligence
		# automation testing (Selenium, PyTest, Behave, BDD, TDD, POM)
		# system scripting

# %%
# 2. Python Principles (DRY, KISS, YAGNI, SOLID, PEP)
	# 1. DRY (Don't Repeat Yourself) = code should not contain duplicate logic or functionality. should be factored into reusable functions.
	# 2. KISS (Keep It Simple, Stupid) = keep the importance of simplicity and avoiding unnecessary complexity. Code should be written in a understandable manner that is easy to read and maintain.
	# 3. YAGNI (You Ain't Gonna Need It) = code should not be written to handle features or functionality that is not yet needed.
	# 4. SOLID (Single Responsibility Principle, Open/Closed Principle, Liskov Substitution Principle, Interface Segregation Principle, Dependency Inversion Principle) = set of principles for object-oriented programming that aims to make code more modular, maintainable, and scalable. Each principle addresses a specific aspect of object-oriented design, such as the separation of concerns, the ability to extend functionality without modifying existing code, and the use of interfaces to decouple dependencies.
	# 5. PEP (Python Enhancement Proposals) = provide a way for the community to contribute to the evolution of the language and ensure that it remains relevant and up-to-date.

# %% [markdown]
# # 3. Comments, Variable, Data Types (int, float, string, bool, complex), Casting, Positive & Negative Slicing

# %%
# 3. Comments, Variable, Data Types (int, float, string, bool, complex), Casting, Positive & Negative Slicing
  # Comments used to:
    # explain Python code.
    # make the code more readable.
    # prevent execution when testing code.
    # starts with a #, and Python will ignore them
print("Hello, world!") # inline comment
# Out:
# Hello, world!

# %%
print('###################################################################################################################################################################')
# Variables
  # containers for storing data values (reserved memory location to store values). when you create a variable you reserve some space in memory.
	# based on the data type of a variable, the interpreter allocates memory and decides what can be stored in the reserved memory.
	# Techniques you can use to make them more readable:

myVariableName = "John" # Camel Case = Each word, except the first, starts with a capital letter:
MyVariableName = "John" # Pascal Case = Each word starts with a capital letter:
my_variable_name = "John" # Snake Case = Each word is separated by an underscore character
  # it is created when we set a value
variable = 10
  # can contain and start with capital and small letters and underscore. can not start with numbers. but can contain numbers. are case sensitive
  # should be unique (values can be change)
var1 = 700
VAR2 = 1000
_var3 = var1 + VAR2
print("variable var1 =", var1)
print("variable VAR2 =", VAR2)
print("variable _var3 =", _var3)
print()
  # can not have spaces between in variable name
  # can not be any of the python keywords
import keyword
print("Python keywords:", keyword.kwlist)
print()
    # do not need to be declared with any particular type, and can even change type after they have been set
    # output variables
      # print() function, to output variables. # Long format of assigning values to variables
a = 100
b = 200
c = 300
print("Value if variable a =", a)
print("Value if variable b =", b)
print("Value if variable c =", c)
print()
      # print() function, to output multiple variables, separated by a comma. # Short format of assigning values to variables
a, b, c = 100, 200, 300
print(a, b, c)
print()
    # global variables
      # created outside of a function are known as global variables
      # used by everyone, both inside of functions and outside
    # overwriting of variables
var1 = 20
print("Value if variable var1 =", var1)
var1 = 10
print("Value if variable var1 =", var1)
print()
print('###################################################################################################################################################################')
# Data Types = is set when you assign a value to a variable
# Primitive data types (Integers, Float, Strings, Boolean) used to represent simple values. have a fixed size and range of values.
  # int = number, positive or negative, without decimals, of unlimited length
age = 34
year_born = 1999
print("Value if age =", age)
print("Type of age is:",type(age))
print("Value if year_born =", year_born)
print("Type of year_born is:", type(year_born))
print()
			# float = number, positive or negative, containing one or more decimals
pi = 3.1415
height = 1.80
depth = 3.5
print("Value if pi =", pi)
print("Type of pi is:", type(pi))
print("Value if height =", height)
print("Type of height is:", type(height))
print("Value if depth =", depth)
print("Type of depth is:", type(depth))
print()
			# bool = true/false
major = True # equivalent with 1
print("Value of major is:", major)
print("Type of major is: ", type(major))
married = False # equivalent with 0
print("Value of married is:", married)
print("Type of major is:", type(married))
print()
			# string "" or '' = a sequence of characters, which can include letters, digits, symbols, and spaces
print("Hello_double_quotes") # Strings in python are surrounded by either single quotation marks, or double quotation marks.
print('Hello_single_quotes') # Strings in python are surrounded by either single quotation marks, or double quotation marks.

string1 = "42"
print("Value of string1 is:", string1)
print("Type of string1 is:", type(string1))
string2 = "True"
print("Value of string2 is:", string2)
print("Type of string2 is:", type(string2))
string3 = "everything from quotes is a string"
print("Value of string3 is:", string3)
print("Type of string3 is:", type(string3))
print()
			# concatenating = obtaining a new string that contains both of the original strings
print("Concatenating of string1 and string2:", string1 + " " + string2)
print()
			# f-string - formatted string
print(f"Concatenating of string1 and string2: {string1} {string2}")
			# complex = numbers are written with a "j" as the imaginary part
num1 = 100 + 20j
print("Value of num1 is:", num1)
print("Type of num1 is:", type(num1))
print()
print('###################################################################################################################################################################')
		# Type Casting = force the conversion of a variable from one type to another
			# If you want to specify the data type of a variable, this can be done with casting
			# int() - create an integer number from an integer, a float (by removing all decimals), or a string (providing the string represents a whole number)
			# float() - create a float number from an integer, a float or a string (providing the string represents a float or an integer)
			# str() - create a string from a wide variety of data types, including strings, integer and float
			# type() = get the data type of any object
var1 = 42
var2 = "42"
var3 = "True"
var4 = "43"

print("Type of num1 var1:", type(var1))
print("Type of num1 var2:", type(var2))
print("Type of num1 var3:", type(var3))
print()

    # var2 -> convert from string to int
    # my_int is created from value from var2, but var2 is not changing the value and also is not changing the data type
my_int = int(var2)
print(f"Value of var2 is: {var2} and Type of var2 is: {type(var2)}")
print(f"Value of my_int is: {my_int} and Type of my_int is: {type(my_int)}")
print()
    # string -> bool
my_bool = bool(var3)
print(f"Value of var3 is: {var3} and Type of var2 is: {type(var3)}")
print(f"Value of my_bool is: {my_bool} and Type of my_bool is: {type(my_bool)}")
print()
    # string -> float
my_float = float(var4)
print(f"Value of var4 is: {var4} and Type of var4 is: {type(var4)}")
print(f"Value of my_float is: {my_float} and Type of my_float is: {type(my_float)}")
print()
    # int -> float
another_float = float(my_int)
print(f"Value of another_float is: {another_float} and Type of another_floar is: {type(another_float)}")
print()
    # int -> bool
true = bool(5) # any value different from 0 is True
false = bool(0)
print(f"Value of true is: {true} and Type of true is {type(true)}")
print(f"Value of false is: {false} and Type of false is {type(false)}") #False <class 'bool'>
print()
    # All variables can be converted to string
my_string = str(another_float)
print(f"Value of my_string is: {my_string} and Type of my string is {type(my_string)}") # 42.0 <class 'str'>
print()
		# input() function
			# helps to take input from the keyboard and save it to a variable.
			# If we do not do type casting, the default data given by the user = string.
			# we can access the values saved in variables as needed
		# \n - newline, go to the next line
# name = input("Write the name: \n")
name = 'Sergiu'
print(f"My name is {name}")
print()
		# strings: index, len(), Positive & negative slicing
			# strings in Python = arrays of bytes representing unicode characters
			# Square brackets can be used to access elements of the string
			# Get the character at position 1 (remember that the first character has the position 0)
a = "Hello, World!"
print("Second character from 'Hello, World!' is:", a[1])
print()
			# loop through the characters in a string, with a for loop
for x in "banana":
  print(x, end=" ")
print()
print()
			# To get the length of a string, use the len() function
a = "Hello, World!"
print("Lenght of varible 'a' is:", len(a))
print()
			# To check if a certain phrase or character is present in a string, we can use the keyword in
txt = "The best things in life are free!"
print("free" in txt)
print()
			# Use it in an if statement:
			# Print only if "free" is present:
txt = "The best things in life are free!"
if "free" in txt:
  print("Yes, 'free' is present.")
print()
			# To check if a certain phrase or character is NOT present in a string, we can use the keyword not in
			# Check if "expensive" is NOT present in the following text
txt = "The best things in life are free!"
print("expensive" not in txt)
print('###################################################################################################################################################################')
			# Slicing Strings
				# return a range of characters by using the slice syntax
				# Specify the start index and the end index, separated by a colon, to return a part of the string
				# sintax: my_str[start_pos, end_pos, step]

				# Positive Indexing = start the slice from the begining of the string
name1 = "Python"
print("Get the characters from position 1 (included) to position 3 (excluded):", name1[1:3])
print()
print("Get the characters from the start to the end of the string:", name1)
print("Get the characters from the start to the end of the string:", name1[:])
print("Get the characters from the start to the end of the string:", name1[0:])
print("Get the characters from the start to the end of the string:", name1[:len(name1)])
print("Get the characters from the start to the end of the string:", name1[: : 1])
print()
b = "Hello, World!"
print("Get the characters from the start to position 5 (not included):", b[:5])
print("Get the characters from position 2, and all the way to the end:", b[2:])
print()
				# Negative indexes = start the slice from the end of the string. last index is -1.
print("Get the characters from the position -2 to position -5 (not included):", b[-5:-2])
print()
				# Positive & Negative slicing
name5 = "I am a very good programmer"
print("I need 'a very goo' for positive and negative indexing", name5[5:15])
print("I need 'a very goo' for positive and negative indexing", name5[-22:-12])
print()
print('###################################################################################################################################################################')
			# String Methods
				# capitalize() = Converts the first character to upper case
txt = "hello, and welcome to my world."
x = txt.capitalize()
print("Converts the first character to upper case from variable x:", x)
print()
				# count()	Returns the number of times a specified value occurs in a string
txt = "I love apples, apple are my favorite fruit"
x = txt.count("apple")
print("The number of times 'apple' occurs in 'txt' string:", x)
print()
				# endswith()	Returns true if the string ends with the specified value
txt = "Hello, welcome to my world."
x = txt.endswith(".")
print("Returns true if the string ends with '.':", x)
				# find()	Searches the string for a specified value and returns the position of where it was found
txt = "Hello, welcome to my world."
x = txt.find("welcome")
print("Searches 'welcome' string and returns the start position of where it was found:", x)
				# index()	Searches the string for a specified value and returns the position of where it was found
txt = "Hello, welcome to my world."
x = txt.index("welcome")
print("Searches 'welcome' string and returns the start position of where it was found:", x)
				# isdecimal()	Returns True if all characters in the string are decimals
txt = "1234"
x = txt.isdecimal()
print("Returns True if all characters in the string are decimals:", x)
				# isdigit()	Returns True if all characters in the string are digits
txt = "50800"
x = txt.isdigit()
print("Returns True if all characters in the string are digits:", x)
				# islower()	Returns True if all characters in the string are lower case
txt = "hello world!"
x = txt.islower()
print("Returns True if all characters in the string are lower case:", x)
				# isnumeric()	Returns True if all characters in the string are numeric
txt = "565543"
x = txt.isnumeric()
print("Returns True if all characters in the string are numeric:", x)
				# isupper()	Returns True if all characters in the string are upper case
txt = "THIS IS NOW!"
x = txt.isupper()
print("Returns True if all characters in the string are upper case:", x)
				# join()	Joins the elements of an iterable to the end of the string
myTuple = ("John", "Peter", "Vicky")
x = "#".join(myTuple)
print("Joins the elements of an iterable to the end of the string:", x)
				# lower()	Converts a string into lower case
txt = "Hello my FRIENDS"
x = txt.lower()
print("Converts a string into lower case:", x)
				# replace()	Returns a string where a specified value is replaced with a specified value
txt = "I like bananas"
x = txt.replace("bananas", "apples")
print("Returns a string where a specified value is replaced with a specified value:", x)
				# split()	Splits the string at the specified separator, and returns a list
txt = "welcome to the jungle"
x = txt.split()
print("Splits the string at the specified separator, and returns a list:", x)
				# startswith()	Returns true if the string starts with the specified value
txt = "Hello, welcome to my world."
x = txt.startswith("Hello")
print("Returns true if the string starts with the specified value:", x)
				# strip()	Returns a trimmed version of the string. Remove spaces at the beginning and at the end of the string
txt = "     banana     "
x = txt.strip()
print("Returns a trimmed version of the string. Remove spaces at the beginning and at the end of the string:", "of all fruits", x, "is my favorite")
				# swapcase()	Swaps cases, lower case becomes upper case and vice versa
txt = "Hello My Name Is PETER"
x = txt.swapcase()
print("Swaps cases, lower case becomes upper case and vice versa:", x)
				# title()	Converts the first character of each word to upper case
txt = "Welcome to my world"
x = txt.title()
print("Converts the first character of each word to upper case:", x)
				# upper()	Converts a string into upper case
txt = "Hello my friends"
x = txt.upper()
print("Converts a string into upper case:", x)
# Out:
# ###################################################################################################################################################################
# variable var1 = 700
# variable VAR2 = 1000
# variable _var3 = 1700
#
# Python keywords: ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
#
# Value if variable a = 100
# Value if variable b = 200
# Value if variable c = 300
#
# 100 200 300
#
# Value if variable var1 = 20
# Value if variable var1 = 10
#
# ###################################################################################################################################################################
# Value if age = 34
# Type of age is: <class 'int'>
# Value if year_born = 1999
# ...

# %% [markdown]
# # 4. Operators (Assignment, Arithmetic, Comparison, Logical, Membership, Bitwise), Dynamic & Static Allocation

# %%
# 4. Operators (Assignment, Arithmetic, Comparison, Logical, Membership, Bitwise), Dynamic & Static Allocation
print('###################################################################################################################################################################')
# Operators
  # used to perform operations on variables and values.
  # used for the purpose of logical and arithmetic operations
  # Types of operators
    # Assignment operators = used to assign values to variables
    #   =, +=, -=, *=, /=, %=, //=, **=, &=, |=, ^=, >>=, <<=

a = 13 # read as: a is assigned with value 13
print("Value of a:", a)
a = 100
print("Value of a:", a)
a = a + 10
print("Value of a+10:", a)
	# shortcut approach for +=
value1 = 1000
print("Value of value1:", value1)
value1 += 1000
print("Value of value1+=1000:", value1)
	# shortcut approach for -=
value1 = 1000
print("Value of value1:", value1)
value1 -= 300
print("Value of value1-=300:", value1)
	# shortcut approach for *=
value1 = 1000
print("Value of value1:", value1)
value1 *= 3
print("Value of value1*3:", value1)
	# shortcut approach for /=
value1 = 1000
print("Value of value1:", value1)
value1 /= 3
print("Value of value1/=3:", value1)
print()
    # Arithmetic operators = used with numeric values to perform common mathematical operations
      # + Addition, - Subtraction, * Multiplication, / Division, % Modulus, ** Exponentiation, // Floor division
        # '+': used to add 2 values.
        # '-': used to subtract the second value from the first value.
        # '*': used to find the product of 2 values.
        # '/': used to find the quotient when first operand is divided by the second. it returns always float value
        # '%' used to find the remainder when first operand is divided by the second. (it depends on arguments if both are int then result is int otherwise float)
        # '**': used to raise the first operand to power of second.
        # '//': used to find the floor of the quotient when first operand is divided by the second.

a = 15
b = 2
print("Addition", a + b)
print("Substraction",a - b)
print("Multiplication", a * b)
print("Division", a / b) # result will be float
print("Modulus", a % b) # result will be modulo. will print the reminder
print("Exponential", a ** b) # power
print("Floor Division", a // b) # division without reminder
print()
# can use some operators with strings
print("Michael" + " " + "Jordan") # concatenation, put two strings together
print("A" + "B" + "C") # can concatenate as many strings we can
print("Michael " * 5) # multiply a string with a number
print()
    # Comparison operators = used to compare two values
				# ==	Equal, != Not equal, > Greater than, < Less than, >= Greater than or equal to, <= Less than or equal to
a = 50
b = 100
print("> a Greater than b:", a > b)
print("< a Less than b:", a < b)
print("==	a Equal b :", a == b)
print("!= a Not equal b:", a != b)
print()
			# Logical operators = used to combine conditional statements
var1, var2, var3 = 100, 200, 300
				# and - returns True if both statements are true
print("< var1 Less than var2:", var1 < var2)
print("> var3 Greater than var1:", var3 > var1)
print("and - returns True if both statements are true:",(var1 < var2) and (var3 > var1))
print()
				# or - returns True if one of the statements is true
print("> var1 Greater than var2:", var1 > var2)
print("> var3 Greater than var2:", var3 > var2)
print("or - returns True if one of the statements is true", (var1 > var2) or (var3 > var2))
print()
				# not - reverse the result, returns False if the result is true
print("not - reverse the result, returns False if the result is true:", not((var1 > var2) or (var3 > var2)))
print()
    # Identity operators = used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location
    	# is - Returns True if both variables are the same object
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x
print("is = Returns True if both variables are the same object:", x is z) # returns True because z is the same object as x
print("is = Returns True if both variables are the same object:", x is y) # returns False because x is not the same object as y, even if they have the same content
print("Equality between x and y:", x == y) # to demonstrate the difference betweeen "is" and "==": this comparison returns True because x is equal to
print()
				# is not - Returns True if both variables are not the same object
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x
print(x is not z) # returns False because z is the same object as x
print(x is not y) # returns True because x is not the same object as y, even if they have the same content
print(x != y) # to demonstrate the difference betweeen "is not" and "!=": this comparison returns False because x is equal to y
print()
    # Membership operators = used to test if a sequence is presented in an object
name1 = 'Python programming'
				# in - Returns True if a sequence with the specified value is present in the object
print('g' in name1)
print('s' in name1)
				# not in - Returns True if a sequence with the specified value is not present in the object
print('s' not in name1)
			# Bitwise operators = used to compare (binary) numbers
				# & 	AND	Sets each bit to 1 if both bits are 1
				# |	OR	Sets each bit to 1 if one of two bits is 1
				# ^	XOR	Sets each bit to 1 if only one of two bits is 1
				# ~	NOT	Inverts all the bits
				# <<	Zero fill left shift	Shift left by pushing zeros in from the right and let the leftmost bits fall off
				# >>	Signed right shift	Shift right by pushing copies of the leftmost bit in from the left, and let the rightmost bits fall off
print('###################################################################################################################################################################')
# Dynamic & Static Allocation
			# Static allocation, int
a, b = 50, 100
print("int, Static allocation:", a + b)
			# Static allocation, float
a, b = 50.2, 100.3
print("float, Static allocation:", a + b)
			# Static allocation, string
string1, string2 = "Michael", "Jordan"
print("string, Static allocation:", string1 + " " + string2)
print()
# 			# Dynamic allocation, int
# value1 = int(input("int: Enter the value of a: "))
# value2 = int(input("int: Enter the value of b: "))
# print(value1 + value2)
# 			# Dynamic allocation, float
# value1 = float(input("float: Enter the value of a: "))
# value2 = float(input("float: Enter the value of b: "))
# print(value1 + value2)
# 			# Dynamic allocation, string
# string1 = str(input("string: Enter the value of a: "))
# string2 = str(input("string: Enter the value of b: "))
# print(string1 + " " + string2)
# Out:
# ###################################################################################################################################################################
# Value of a: 13
# Value of a: 100
# Value of a+10: 110
# Value of value1: 1000
# Value of value1+=1000: 2000
# Value of value1: 1000
# Value of value1-=300: 700
# Value of value1: 1000
# Value of value1*3: 3000
# Value of value1: 1000
# Value of value1/=3: 333.3333333333333
#
# Addition 17
# Substraction 13
# Multiplication 30
# Division 7.5
# Modulus 1
# Exponential 225
# Floor Division 7
#
# Michael Jordan
# ABC
# Michael Michael Michael Michael Michael
#
# > a Greater than b: False
# < a Less than b: True
# ==	a Equal b : False
# != a Not equal b: True
#
# < var1 Less than var2: True
# > var3 Greater than var1: True
# and - returns True if both statements are true: True
#
# > var1 Greater than var2: False
# > var3 Greater than var2: True
# or - returns True if one of the statements is true True
#
# ...

# %% [markdown]
# # 5. Data Stucture / Data Collection (List, Tuple, Dictionary, Sets)

# %%
# 5. Data Stucture / Data Collection (List, Tuple, Dictionary, Sets)
    # = "containers"/collection of data that can store and group different data types
    # = useful for working with large amounts of data and performing operations like filtering, sorting, and searching
  # List
    # ordered (items have a defined order, and that order will not change) (If you add new items to a list, the new items will be placed at the end of the list)
		# changeable (mutable) (can change, add or remove items after the list has been created), allow duplicates (lists can have items with the same value)
    # created using square brackets []
    # to determine how many items a list has, use the len() function
    # list items are indexed, the first item has index [0], the second item has index [1]

thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print("This is a list 'thislist':", thislist)
    # list length = To determine how many items a list has, use the len() function
thislist = ["apple", "banana", "cherry"]
print("Length of the list 'thislist' is:", len(thislist))
    # list items
    	# items can be of any data type, and you can have multiple values of different data types
list2 = ["hello", 800, True, False, (60 + 49j), 56.87]
print("List with different data types:", list2)
			# type()
				# lists are defined as objects with the data type 'list'
mylist = ["apple", "banana", "cherry"]
print(type(mylist))
			# list() constructor when creating a new list
thislist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thislist)
print()
			# Access items list by referring to the index number
				# positive indexing
thislist = ["apple", "banana", "cherry"]
print("Possitive indexing. Take the item from position 1:", thislist[1])
				# negative indexing = start from the end -1 refers to the last item
thislist = ["apple", "banana", "cherry"]
print("Negative indexing. Take the item from position -1:", thislist[-1])
print()
				# range of indexes = by specifying where to start and where to end the range. the return value will be a new list with the specified items
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print("Items from position 2 (included) to position 5 (not included)", thislist[2:5])
				# returns the items from the beginning to, but NOT including, "kiwi"
print("Items from the beginning to, but NOT including 'kiwi'", thislist[:4])
				# returns the items from "cherry" to the end
print("Items from 'cherry' to the end", thislist[2:])
				# returns the items from "orange" (-4) to, but NOT including "mango" (-1)
print("Items from 'orange' (-4) to, but NOT including 'mango' (-1)", thislist[-4:-1])
print()
				# To determine if a specified item is present in a list use the in keyword
thislist = ["apple", "banana", "cherry"]
if "apple" in thislist:
  print("Yes, 'apple' is in the fruits list")
  			# Change list items item value, refer to the index number
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print("New list with second item changed: from 'banana' to 'blackcurrant'", thislist)
				# change a range of item value = define a list with the new values, and refer to the range of index numbers where you want to insert the new values
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print("New list with the items from postion 1 to 3 changed:", thislist)
				# insert items = insert() method inserts an item at the specified index
thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print("New list with inserting 'watermelon' in position 2", thislist)
			# Add list items (append items) = to the end of the list, use the append() method
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print("New list with appending 'orange' at the end of the list:", thislist)
				# extend list = To append elements from another list to the current list, use the extend() method
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print("New list extended from 'thislist' and 'tropical':", thislist)
			# Remove list items = remove() method removes the specified item
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print("New list with item 'banana' removed:", thislist)
				# remove specified index = pop() method removes the specified index. If you do not specify the index, the pop() method removes the last item.
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print("New list with the second item removed:", thislist)
thislist.pop()
print("New list with the last item removed:", thislist)
					# del keyword also removes the specified index
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print("New list with the first item removed using 'del':", thislist)
					# del keyword can also delete the list completely
del thislist # Delete the entire list
				# clear the list = clear() method empties the list
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print("New list after cleaning:", thislist)
print()
print('###################################################################################################################################################################')
			# Loop list
				# for loop: loop through a list items
thislist = ["apple", "banana", "cherry"]
for x in thislist:
  print(x)
print()
				# for loop: loop through the index numbers
					# Use the range() and len() functions to create a suitable iterable
thislist = ["apple", "banana", "cherry"]
for i in range(len(thislist)):
  print(thislist[i])
print()
				# while loop: loop through all the index numbers
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1
print()
			# List comprehension = offers a short syntax when you want to create a new list based on the values of an existing list, in a single, readable line
				# loop using list comprehesion. offers the shortest syntax for looping through lists.
				# Syntax: newlist = [expression for item in iterable if condition == True]
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist]
			# Example:
				# Based on a list of fruits, you want a new list, containing only the fruits with the letter "a" in the name.
  				# Without list comprehension you will have to write a for statement with a conditional test inside
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []
for x in fruits:
  if "a" in x:
    newlist.append(x)
print("Looping through a list using for loop:", newlist)
  				# With list comprehension you can do all that with only one line of code
newlist = [x for x in fruits if "a" in x]
print("Looping through a list using list comprehension:", newlist)
print()
			# Sort list
				# sort the list alphabetically, numerically in ascending, by default
				# Sort the list alphabetically
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print("Sort ascending", thislist)
				# Sort the list numerically:
thislist = [100, 50, 65, 82, 23]
thislist.sort()
print("Sort ascending", thislist)
				# sort descending, use the keyword argument reverse = True
thislist.sort(reverse = True)
print("Sort descending:", thislist)
print()
			# Copy list
				# You cannot copy a list simply by typing list2 = list1, because: list2 will only be a reference to list1, and changes made in list1 will automatically also be made in list2.
				# Make a copy of a list with the copy() method
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print("New list copied from 'thislist' to 'mylist' using 'copy()':", mylist)
				# Another way to make a copy is to use the built-in method list()
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print("New list copied from 'thislist' to 'mylist' using 'list()':", mylist)
print()
			# Join 2 list	using the + operator
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]
list3 = list1 + list2
print("Join: list1 and list2 to list3:", list3)
				# appending all the items from list2 into list1
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]
for x in list2:
  list1.append(x)
print("Append: list2 to list1 using for loop:", list1)
				# use the extend() method, which purpose is to add elements from one list to another list
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]
list1.extend(list2)
print("Append: list2 to list1 using extend():", list1)
			# List methods
				# append() = Adds an element at the end of the list
				# clear()	= Removes all the elements from the list
				# copy() = Returns a copy of the list
				# count() = Returns the number of elements with the specified value
				# extend() = Add the elements of a list (or any iterable), to the end of the current list
				# index()	= Returns the index of the first element with the specified value
				# insert() = Adds an element at the specified position
				# pop() = Removes the element at the specified position
				# remove() = Removes the item with the specified value
				# reverse() = Reverses the order of the list
				# sort() = Sorts the list
			# nested list = list in list
list3 = [[40, 90], [40, 98], [34, 78, 67]]
print("Nested list (list in list):", list3)

# nested list (lists that contains other lists)
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n]
print(x)
print(x[0])
print(x[0][1])
print('###################################################################################################################################################################')
		# Tuple
			# ordered (the items have a defined order, and that order will not change)
			# unchangeable (immutable) (cannot change, add or remove items after the tuple has been created)
			# allow duplicates (tuple can have items with the same value)
			# created using round brackets ()
			# To create a tuple with only one item, you have to add a comma after the item
			# tuple items indexed, the first item has index [0], the second item has index [1]

thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print("This is tuple 'thistuple':", thistuple)
			# Tuple Length = To determine how many items a tuple has, use the len() function
thistuple = ("apple", "banana", "cherry")
print("Length of the tuple is:", len(thistuple))
print()
			# Create Tuple With One Item = you have to add a comma after the item, otherwise Python will not recognize it as a tuple.
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
			# Tuple items can be of any data type, and you can have multiple values of different data types
tuple2 = ("hello", 800, True, False, (60 + 49j), 56.87)
print(tuple2)
			# type() = tuple are defined as objects with the data type 'tuple'
mytuple = ("apple", "banana", "cherry")
print(type(mytuple))
			# Access Tuple =	tuple() constructor to make a tuple
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
print()
				# Positive indexing = access tuple items by referring to the index number, inside square brackets
thistuple = ("apple", "banana", "cherry")
print("Possitive indexing. Take the item from position 1:", thistuple[1])
				# Negative indexing = start from the end. -1 refers to the last item, -2 refers to the second last item
thistuple = ("apple", "banana", "cherry")
print("Negative indexing. Take the item from position -1:", thistuple[-1])
print()
				# range of indexes by specifying where to start and where to end the range. the return value will be a new tuple with the specified items.
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print("Items from position 2 (included) to position 5 (not included):", thistuple[2:5])
				# returns the items from the beginning to, but NOT included, "kiwi"
print("Items from the beginning to, but NOT including 'kiwi':", thistuple[:4])
				# returns the items from "cherry" and to the end
print("Items from 'cherry' to the end:", thistuple[2:])
				# returns the items from index -4 (included) to index -1 (excluded)
print("Items from 'orange' (-4) to, but NOT including 'mango' (-1):", thistuple[-4:-1])
print()
				# To determine if a specified item is present in a tuple use the in keyword
thistuple = ("apple", "banana", "cherry")
if "apple" in thistuple:
  print("Yes, 'apple' is in the fruits tuple")
			# Update Tuples
				# Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.
				# But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple
x = ("apple", "banana", "cherry")
print("Initial tuple before update:", x)
y = list(x)
y[1] = "kiwi"
x = tuple(y)
print("Initial tuple after update using list:", x)
print()
				# Add Items
					# they do not have a built-in append() method, but there are other ways to add items to a tuple.
					# 1. convert it into a list, add your item(s), and convert it back into a tuple.
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)
print("Append item to a tuple using converting to list:",thistuple)
					# 2. Add tuple to a tuple. create a new tuple with the item(s), and add it to the existing tuple
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y
print("Append tuple cu another tuple:", thistuple)
				# Remove Items = cannot remove items from it, but you can use the same workaround as we used for changing and adding tuple items
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)
print("New tuple with removing 'apple' using list:", thistuple)
				# delete the tuple completely
thistuple = ("apple", "banana", "cherry")
del thistuple
# print(thistuple) #this will raise an error because the tuple no longer exists
print()
			# Pack/Unpack Tuples
				# When we create a tuple = Packing a tuple
fruits = ("apple", "banana", "cherry")
				# When we extract the values back into variables = unpacking a tuple
fruits = ("apple", "banana", "cherry")
(green, yellow, red) = fruits
print("Unpacking items from fruits:")
print(green)
print(yellow)
print(red)
print('###################################################################################################################################################################')
			# Loop Tuples
				# loop through the tuple items by using a for loop
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
print()
				# loop through the tuple items by referring to their index number. Use the range() and len() functions to create a suitable iterable
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
print()
				# loop through the tuple items by using a while loop. Use the len() function to determine the length of the tuple, then start at 0 and loop your way through the tuple items by referring to their indexes. Remember to increase the index by 1 after each iteration
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 1
print()
			# Join Tuples = two or more tuples you can use the + operator
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)
tuple3 = tuple1 + tuple2
print("Join tuple1 and tuple2 in to tuple3:", tuple3)
				# multiply the content of a tuple a given number of times, you can use the * operator
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2
print("Tuple after multiplying the items:", mytuple)
			# Tuple Methods
				# count()	= Returns the number of times a specified value occurs in a tuple
				# index() = Searches the tuple for a specified value and returns the position of where it was found
			# nested tuple = tuple inside the tuple
tuple2 = ((40, 90), (40, 98), (34, 78, 67))
print("Nested Tuple = tuple inside the tuple:", tuple2)
print('###################################################################################################################################################################')
		# Dictionary
			# ordered
			# changeable (can change, add or remove items after the dictionary has been created)
			# Do not allow duplicates (cannot have two items with the same key)
			# used to store data values in key:value pairs. created using curly brackets {}
			# Values of dictionaries items can be of any data type. Cannot have two items with the same key
			# To determine how many items a dictionary has, use the len() function

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print("Dictionary: ", thisdict)
			# Dictionary Length
				# To determine how many items a dictionary has, use the len() function
print("Length of the dictionary:", len(thisdict))
			# Data Types
				# The values in dictionary items can be of any data type
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}
print("Dictionary with different data types:", thisdict)
print("Value of the key 'brand':", thisdict['brand'])
			# type() = dictionaries are defined as objects with the data type 'dict'
print("Type: ", type(thisdict))
			# dict() constructor to make a dictionary
thisdict = dict(name = "John", age = 36, country = "Norway")
print("Create a dictionary using dict() keyword:", thisdict)
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}
			# Accessing Items
				# by referring to its key name, inside square brackets
key_name = thisdict["brand"]
print("Key name of 'brand':", key_name)
				# method called get() that will give you the same result
key_name = thisdict.get("brand")
print("Key name of 'brand':", key_name)
				# keys() method will return a list of all the keys in the dictionary
dict_keys = thisdict.keys()
print("Dictionary keys are:", dict_keys)
				# values() method will return a list of all the values in the dictionary
dict_values = thisdict.values()
print("Dictionary values are:", dict_values)
				# items() method will return each item in a dictionary, as tuples in a list
dict_items = thisdict.items()
print("Dictionary items are:", dict_items)
print()
				# To determine if a specified key is present in a dictionary use the 'in' keyword
if "model" in thisdict:
  print("Yes, 'model' is one of the keys in the thisdict dictionary")
				# Change Dictionary Items = change the value of a specific item by referring to its key name
thisdict["year"] = 2018
				# update() method will update the dictionary with the items from the given argument
thisdict.update({"brand":"Duster"})
			# Add Dictionary Items = Adding an item to the dictionary is done by using a new index key and assigning a value to it
thisdict["speed"] = "120 km/h"
print("New dictionary with the item speed", thisdict)
				# update() method will update the dictionary with the items from a given argument. If the item does not exist, the item will be added.
thisdict.update({"speed": "140 km/h"})
print("New dictionary with the item speed updated", thisdict)
			# Remove Dictionary Items
			# 	pop() method removes the item with the specified key name
thisdict.pop("speed")
print("New dictionary with the item speed removed:", thisdict)
				# popitem() method removes the last inserted item
thisdict.popitem()
print("New dictionary with the last item removed:", thisdict)
				# del keyword removes the item with the specified key name
del thisdict["electric"]
print("New dictionary with the item 'electric' removed:", thisdict)
				# clear() method empties the dictionary
thisdict.clear()
print("Cleaned dictionary:", thisdict)
print('###################################################################################################################################################################')
			# Loop Through a Dictionary
				# by using a for loop = the return value are the keys of the dictionary, but there are methods to return the values as well.
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}
		# Print all key names in the dictionary,
print("Keys of dictionary: ")
for x in thisdict:
  print(x)
print()
		# Print all values in the dictionary
print("Values of dictionary: ")
for x in thisdict:
  print(thisdict[x])
print()
print("Values of dictionary: ")
		# use the values() method to return values of a dictionary
for x in thisdict.values():
  print(x)
print()
		# keys() method to return the keys of a dictionary
print("Keys of dictionary: ")
for x in thisdict.keys():
  print(x)
print()
		# Loop through both keys and values, by using the items() method
print("Items of the dictionary:")
for x, y in thisdict.items():
  print(x, y)
print()
			# Copy a Dictionary
				# Make a copy of a dictionary with the copy() method
mydict = thisdict.copy()
print("New copy of the dictionary: ", mydict)

				# use the built-in function dict()
mydict = dict(thisdict)
print("Creating a new dictionary using dict() keyword:", mydict)

			# Nested Dictionaries = A dictionary that can contain dictionaries
				# dictionary that contain three dictionaries
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print("Nested Dictionary with members of family", myfamily)
print()
			# To add three dictionaries into a new dictionary
			# 	Create three dictionaries, then create one dictionary that will contain the other three dictionaries
child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}
			# To access items from a nested dictionary, you use the name of the dictionaries, starting with the outer dictionary
print("Name of child2 from myfamily dictionary:", myfamily["child2"]["name"])
print()
		# Dictionary Methods
			# clear() = Removes all the elements from the dictionary
			# copy() = Returns a copy of the dictionary
			# fromkeys() = Returns a dictionary with the specified keys and value
			# get() = Returns the value of the specified key
			# items() = Returns a list containing a tuple for each key value pair
			# keys() = Returns a list containing the dictionary's keys
			# pop() = Removes the element with the specified key
			# popitem() = Removes the last inserted key-value pair
			# setdefault() = Returns the value of the specified key. If the key does not exist: insert the key, with the specified value
			# update() = Updates the dictionary with the specified key-value pairs
			# values() = Returns a list of all the values in the dictionary
print('###################################################################################################################################################################')
		# Sets
			# unordered and unchangeable (immutable) (cannot change, add or remove items after the tuple has been created), do not allow duplicates
			# created using round brackets {}
			# used to store multiple items of any data type in a single variable
			# Sets cannot have two items with the same value
thisset = {"apple", "banana", "cherry", "apple"}
print("This is a set 'thisset':", thisset)
		# To determine how many items a set has, use the len() function
thisset = {"apple", "banana", "cherry"}
print("Length of the set 'thisset' is", len(thisset))
		# Set items can be of any data type
set1 = {"abc", 34, True, 40, "male"}
print("Different data types of set", set1)
		# sets are defined as objects with the data type 'set'
myset = {"apple", "banana", "cherry"}
print("Type of myset is:", type(myset))

		# use the set() constructor to make a set
thisset = set(("apple", "banana", "cherry")) # note the double round-brackets
print("Create a set using set() keyword:", thisset)

		# Access Items
		# 	Loop through the set items using a for loop, and print the values
thisset = {"apple", "banana", "cherry"}
for x in thisset:
  print(x)
print()
			# Check if a specified value is present in a set, by using the in keyword
print("Check if a specified value is present in a set:", "banana" in thisset)
		# Add Items (Once a set is created, you cannot change its items, but you can add new items.)
		# 	To add one item to a set use the add() method
thisset = {"apple", "banana", "cherry"}
thisset.add("orange")
print("New set after adding the 'orane':", thisset)

			# Add Sets: To add items from another set into the current set, use the update() method.
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}
thisset.update(tropical)
print("New set, after adding a new set to another:", thisset)
			# Add Any Iterable: The object in the update() method does not have to be a set, it can be any iterable object (tuples, lists, dictionaries etc.).
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]
thisset.update(mylist)
print("New set after adding the new iterable object to the set:", thisset)

		# Remove Item in a set, use the remove(), or the discard() method
		# 	Remove "banana" by using the remove() method
thisset.remove("banana")
print("New set after removing 'banana' from the set:", thisset)

			# Remove "kiwi" by using the discard() method
thisset.discard("kiwi")
print("New set after removing 'kiwi' from the set:", thisset)
			# pop() method to remove an item, but this method will remove a random item, so you cannot be sure what item that gets removed. The return value of the pop() method is the removed item
thisset = {"apple", "banana", "cherry"}
x = thisset.pop()
print("Item than supose to be removed:", x)
print("New set after removing a random item:", thisset)

			# clear() method empties the set
thisset = {"apple", "banana", "cherry"}
thisset.clear()
print("Clearing the set:", thisset)

			# del keyword will delete the set completely
thisset = {"apple", "banana", "cherry"}
del thisset
print('###################################################################################################################################################################')
		# Loop Sets
		# 	loop through the set items by using a for loop
thisset = {"apple", "banana", "cherry"}
for x in thisset:
  print(x)
print()
		# Join Sets = union() method that returns a new set containing all items from both sets
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set3 = set1.union(set2)
print("New set3 created from join set1 and set2:", set3)
			# update() method that inserts all the items from one set into another
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set1.update(set2)
print("New set inserting the items from set2 to set1:", set1)

			# intersection_update() method will keep only the items that are present in both sets
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
x.intersection_update(y)
print("Intersection of sets. Items from both sets:", x)

			# intersection() method will return a new set, that only contains the items that are present in both sets
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
z = x.intersection(y)
print("Intersection of sets. Items from both sets:", z)

			# symmetric_difference_update() method will keep only the elements that are NOT present in both sets
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
x.symmetric_difference_update(y)
print("New set with only the elements that are NOT present in both sets", x)

			# symmetric_difference() method will return a new set, that contains only the elements that are NOT present in both sets
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
z = x.symmetric_difference(y)
print("New set only the elements that are NOT present in both sets", z)

		# Set Methods
			# add() = Adds an element to the set
			# clear() = Removes all the elements from the set
			# copy() = Returns a copy of the set
			# difference() = Returns a set containing the difference between two or more sets
			# difference_update() = Removes the items in this set that are also included in another, specified set
			# discard() = Remove the specified item
			# intersection() = Returns a set, that is the intersection of two other sets
			# intersection_update() = Removes the items in this set that are not present in other, specified set(s)
			# isdisjoint() = Returns whether two sets have a intersection or not
			# issubset() = Returns whether another set contains this set or not
			# issuperset() = Returns whether this set contains another set or not
			# pop() = Removes an element from the set
			# remove() = Removes the specified element
			# symmetric_difference() = Returns a set with the symmetric differences of two sets
			# symmetric_difference_update() = inserts the symmetric differences from this set and another
			# union() = Return a set containing the union of sets
			# update() = Update the set with the union of this set and others
# Out:
# This is a list 'thislist': ['apple', 'banana', 'cherry', 'apple', 'cherry']
# Length of the list 'thislist' is: 3
# List with different data types: ['hello', 800, True, False, (60+49j), 56.87]
# <class 'list'>
# ['apple', 'banana', 'cherry']
#
# Possitive indexing. Take the item from position 1: banana
# Negative indexing. Take the item from position -1: cherry
#
# Items from position 2 (included) to position 5 (not included) ['cherry', 'orange', 'kiwi']
# Items from the beginning to, but NOT including 'kiwi' ['apple', 'banana', 'cherry', 'orange']
# Items from 'cherry' to the end ['cherry', 'orange', 'kiwi', 'melon', 'mango']
# Items from 'orange' (-4) to, but NOT including 'mango' (-1) ['orange', 'kiwi', 'melon']
#
# Yes, 'apple' is in the fruits list
# New list with second item changed: from 'banana' to 'blackcurrant' ['apple', 'blackcurrant', 'cherry']
# New list with the items from postion 1 to 3 changed: ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']
# ...

# %% [markdown]
# # 6. Conditional (if, if...else, if...elif...else, nested if) & Iterative (while, for) & Transfer statements (break, continue, pass)

# %%
# Python provides several control flow structures that allow you to change the order of execution based on certain conditions or loops
		# Control flow = the order in which statements are excuted in a program.
			# 1. Conditional statements = decision-making statement = supports the usual logical conditions from mathematics
				# Equals: a == b
				# Not Equals: a != b
				# Less than: a < b
				# Less than or equal to: a <= b
				# Greater than: a > b
				# Greater than or equal to: a >= b
			# 1. if = allows you to execute a block of code if a certain condition is met
a = 500
if (a > 20):
  print(f"Number {a} is more than 20")
      # 2. if - else = allows you execute a different block of code if the condition in not met
a = 5
if a > 20:
  print(f"Number {a} is more than 20")
else:
  print(f"Number {a} is less than 20")
print()
# program that take dynamic input and check that the number is even or odd
# number = int(input("Enter the number to check if its is odd or even: "))
number = 3
if number % 2 ==0:
  print(f"Number is {number} and it is even")
else:
  print(f"Number is {number} and it is odd")
print()
			# 3. if-elif-else = somethimes you might have more than two possible outcomes. in that case, you can use an 'elif' statement to check additional conditions
        # elif block: when we have to check multiple condition
        # problem with multiple 'if' block
# marks = int(input("Enter the marks of the student "))
marks = 84
print("The marks is ", marks)

if marks >= 90:
  print("A grade")
elif marks >= 80 and marks < 90:
  print("B grade")
elif marks >= 70 and marks < 80:
  print("C grade")
else:
  print("Failed")
print()
      # 4. nested if-else =  if inside if
age = 25
if age > 18:
    print("You are major")
    if age > 65:
        print("you are retired")
    else:
        print("you are adult")
else:
    print("You are minor")
    if age < 2:
        print("you are a baby")
    elif age <= 12:
        print("you are child")
    else:
        print("you are adolescent")
print()
  # 2. Iterative statements = Loops = iterating (repetition) over a sequence (list, tuple, dictionary, set, string)
    # 1. for / for each loop
      # 1. how many times you want to repeat a block of code
      # 2. to iterate over a sequence (list, tuple, dictionary, set, a string)
    # Looping Through a String
# the keyword 'end' can be used to avoid the newline after the output, or the output with a different string
for x in "banana":
  print(x, end=" ")
print()
		# Looping Through a List
fruits_list = ["apple", "banana", "cherry"]
for fruit in fruits_list:
  print(fruit)
print()
		# Looping Through a Tuple
fruits_tuple = ("apple", "banana", "cherry")
for fruit in fruits_tuple:
  print(fruit)
print()
  	# The break Statement = stop the loop before it has looped through all the items
    # Exit the loop when x is "banana"
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
  if x == "banana":
    break
print()
		# Continue statement = stop the current iteration of the loop, and continue with the next
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    continue
  print(x)
print()
		# range() Function = loop through a set of code a specified number of times
		# 			 = returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and ends at a specified number.
for x in range(6):
  print(x, end=" ")
print()
		# range() function defaults to 0 as a starting value, however it is possible to specify the starting value by adding a parameter: range(2, 6), which means values
    # from 2 to 6 (but not including 6)
for x in range(2, 6):
  print(x, end=" ")
print()
		# range() function defaults to increment the sequence by 1, however it is possible to specify the increment value by adding a third parameter: range(2, 30, 3)
for x in range(2, 30, 3):
  print(x, end=" ")
print()
 		# 'else' in a for loop = specifies a block of code to be executed when the loop is finished
for x in range(6):
  print(x, end=" ")
else:
  print("Finally finished!")
		# nested loop is a loop inside a loop = "inner loop" will be executed one time for each iteration of the "outer loop"
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
  for y in fruits:
    print(x, y)
print()
  	# pass statement = for loops cannot be empty, but if you for some reason have a for loop with no content, put in the pass statement to avoid getting an error
for x in [0, 1, 2]:
  pass
  # 2. while loop = repeat a block of code as long as condition is true
i = 1
while i < 6:
  print(i, end=" ")
  i += 1
print()
    # break statement we can stop the loop even if the while condition is true
i = 1
while i < 6:
  print(i, end=" ")
  if i == 3:
    break
  i += 1
print()
		# continue statement we can stop the current iteration, and continue with the next
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
		# else statement we can run a block of code once when the condition no longer is true
i = 1
while i < 6:
  print(i, end=" ")
  i += 1
else:
  print("i is no longer less than 6")
print()

  # 3. Transfer statements = used in Conditional & Iterative statements
    # 1. break = exit a loop early if a certain condition is met
    # 2. continue = skip the rest of the current iteration and move on the next one
    # 3. pass = if you for some reason have a loop with no content, put in the pass statement to avoid getting an error
# Out:
# Number 500 is more than 20
# Number 5 is less than 20
#
# Number is 3 and it is odd
#
# The marks is  84
# B grade
#
# You are major
# you are adult
#
# b a n a n a
# apple
# banana
# cherry
#
# apple
# banana
# cherry
#
# apple
# banana
#
# apple
# cherry
#
# 0 1 2 3 4 5
# 2 3 4 5
# 2 5 8 11 14 17 20 23 26 29
# 0 1 2 3 4 5 Finally finished!
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry
#
# 1 2 3 4 5
# 1 2 3
# 1
# 2
# 4
# 5
# 6
# 1 2 3 4 5 i is no longer less than 6

# %% [markdown]
# #	7. Functions & Parameters & High Order Function (map(), filter(), reduce(), lambda()) & Iterator & Decorator & Generator

# %%
# Function
  # = block of code which only runs when it is called (Write once, use n times). You can pass data, known as parameters, into a function.
  # A function can return data as a result
  # = Example: Put some commonly or repeatedly done task together and make a function so that instead of writing the same code again and again for different inputs,
  # we can call the function to reuse code contained in it over and over again

  # 1. Function buided in Python
    # print() = print the content
    # input() = take the date from keyword
    # list() = create a list
    # tuple() = create a tuple
    # type() = shows the data type of an item
    # len() = returns the length of the string.
    # min() = returns the item with the lowest value
    # max() = returns the item with the highest value
    # sort() = sorts the list ascending by default
  # 2. Function
    # Creating a Function = is defined using the def keyword
def my_function():
  print("Hello from a function")
			# Calling a Function = To call a function, use the function name followed by parenthesis
my_function()
print()
  # 3. Function with No parameter = not passing any parameter while defining the function
def Hello():
  print("My name is Sergiu, I am a student")
Hello()
print()
  # 4. Function with parameter = passing any parameter (inside the parentheses. You can add as many arguments as you want, just separate them with a comma)
    # while defining the function
  # parameter / argument = value that are passed to the function when it is called
def maths1(value1, value2):
  print(value1 + value2)
  print(value1 - value2)
  print(value1 * value2)
  print(value1 / value2)
maths1(300, 20)
print()
		# 5. Function with parameter and with return = used to end the execution of the function call and 'returns' the result (value of the expression following the return keyword)
    # to the caller. The statements after the return statement are not executed. the statements after the return statements are not executed.
    # (passing any parameter while defining the function)
def func2(c, d):
  return c + d
print(func2(3, 4))
		# 6. High Order Function = function that takes one or more functions as arguments, or returns a function as its result
			# lambda() = small anonymous function that can be defined without a name. can take any number of arguments, but can only have one expression. execution time is faster
    # then normal functions
func11 = lambda y: y + 5
print(func11(100))
		  # map() = method to do one-to-one transformation of a collection and by giving the map method it will map to each and every element in the collection and it will return
      # the result as another collection
list1 = [1, 2, 3, 4, 5, 6]
def cube(x):
  return x * x * x
list3 = list(map(cube, list1))
print(list3)
			# filter() = constructs an iterator from elements of an iterable for which a function returns true
def hello(x):
  return x > 4
list4 = list(filter(hello, list1))
print(list4)
			# reduce() = applies a given function to the iterables and returns a single value
from functools import reduce

list1 = [1, 2, 3, 4, 5, 6, 7]
def my_sum(x, y):
  return x + y
reduce(my_sum, list1)
# Out:
# Hello from a function
#
# My name is Sergiu, I am a student
#
# 320
# 280
# 6000
# 15.0
#
# 7
# 105
# [1, 8, 27, 64, 125, 216]
# [5, 6]
# 28

# %% [markdown]
# # 8. OOP Principles (class, object, methods, atributes, constructor, self, Inheritance, Encapsulation, Abstractization, Polymorfism)

# %%
# class = blueprint for creating objects that share similar properties and behaviors. Each class can have attributes (data) and methods (functions) that define its behavior.
# Classes are defined using the "class" keyword and can be instantiated (created) using the class constructor.

  # Ex: Create a class named MyClass, with a property named x
class MyClass:
  x = 5
# object = entity that has state and behavior. When we define a class, it needs to create an object to allocate the memory
  # Ex: Create an object named p1, and print the value of x
p1 = MyClass()
print(p1.x)
# methods = functions that belong to the object
  # Ex: Insert a function that prints a greeting, and execute it on the p1 object
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(self):
    print("Hello my name is " + self.name)

p1 = Person("John", 36)
p1.myfunc()
# atributes = properties of the object
# constructor = special function/method that gets called automatically when you create the object. Name: __init__
# Parametrized Constructor = apart from self, if you pass anything in constructor -> becomes -> parametrized constructor

# __init__ = Stands for initiate. is executed when the class is being initiated. takes self as the first parameter, followed by other parameters representing the initial
# values for the object's attributes. It is called automatically when an object is created from a class.
# Ex: Create a class named Person, use the __init__() function to assign values for name and age

class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age
p1 = Person("John", 36)
print(p1.name)
print(p1.age)
# self = default parameter that you have to pass, and there is not need to pass the value for that parameter while calling the function. is a reference to the current instance
# of the class, and is used to access variables that belong to the class.
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(abc):
    print("Hello my name is " + abc.name)

p1 = Person("John", 36)
p1.myfunc()
# super() function that will make the child class inherit all the methods and properties from its parent
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)

x = Student("Mike", "Olsen")
x.printname()
# Inheritance = allows us to define a class that inherits all the methods and properties from another class
  # Parent class = class being inherited from, also called base class.
  # Child class = class that inherits from another class, also called derived class

# Types of Inheritance
  # 1. Single Inheritance
  # 2. Multilevel Inheritance
  # 3. Hierarhical Inheritance
  # 4. Multiple Inheritance

  # Ex: Create a Parent Class: class named Person, with firstname and lastname properties, and a printname method
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)
# Use the Person class to create an object, and then execute the printname method:
x = Person("John", "Doe")
x.printname()
# Ex: Create a Child Class: class named Student, which will inherit the properties and methods from the Person class. Student class has the same properties and methods as
# the Person class
class Student(Person):
  pass
# Ex: Student class to create an object, and then execute the printname method
x = Student("Mike", "Olsen")
x.printname()
# Encapsulation = restrict access to methods and variables that prevents data from direct modification. the code and data are wrapped together within a single unit. prevents your code from unauthorized user's. helps to access the private data members outside class (access data member from outside the class)
  # Private variables = variables that can't be accessed from outside of class
  # Public variables = variables that can be accessed from outside of the class
  # Ex: public variable
class Test1:
  a = 50 # public variable
obj1 = Test1()
print(obj1.a)
		  # Ex: private variable
class Test2():
  __a = 100 # private variable
obj2 = Test2()
# print(obj2.__a)
			# Ex: Normal function
class Test3():
  def func1(self):
    print("I am normal function")
obj3 = Test3()
obj3.func1()
			# Ex: private function
# class Test4():
#   def __func2(self):
#     print("I am private function")
# obj4 = Test4()
# obj4.__func2()
  # Access the private data members outside class (access data member from outside the class)
  # Approach = using constructors
class Test5:
  __b = 200
  def __init__(self):
    print(self.__b)
obj5 = Test5()
			# Approach = using function
class Test6():
  def __func2(self):
    print("I am a private function")
  def __init__(self):
    self.__func2()
obj6 = Test6()
			# Approach - using function
class Test7():
  def __func3(self):
    print("I am a private function")
  def help(self):
    self.__func3()
obj7 = Test7()
obj7.help()

# Abstractization
  # An abstract class contains methods without a body but also methods with defined logic
  # An Interface contains only abstract methods
  # These classes will be inherited by the child classes which will have to write the logic of the methods
# Polymorphism = implement method overriting. there are functions with the same name but different behaviour.
class Test8():
  def func1(self):
    print("I am the function of parent")
class Test9(Test8):
  def func1(self):
    print("I am the function of child")
obj9 = Test9()
obj9.func1()

# Exception and error handling = using try/except blocks. allows to handle errors and prevent the program from crashing.
# Ex: use a try/except block to handle a division by zero error:
try:
  x = 10 / 0
except ZeroDivisionError:
  print("Error: Division by zero!")
# the code inside the try block will be executed, and if a ZeroDivisionError is raised, the code inside the except block will be executed instead.
# Out:
# 5
# Hello my name is John
# John
# 36
# Hello my name is John
# Mike Olsen
# John Doe
# Mike Olsen
# 50
# I am normal function
# 200
# I am a private function
# I am a private function
# I am the function of child
# Error: Division by zero!
