# %% [markdown]
# # Normal Distribution (most common values are close to mean value) = Gaussian distribution

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
Dataset = pd.read_csv("/content/drive/MyDrive/MyPersonalDataset/placement.csv")
Dataset
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
import seaborn as sns
sns.distplot(Dataset['cgpa'])
# Out:
# <ipython-input-4-326f5f390a4c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Dataset['cgpa'])
# <Axes: xlabel='cgpa', ylabel='Density'>

# %%
Dataset['cgpa'].mean()
# Out:
# 6.96124

# %%
Dataset['cgpa'].median()
# Out:
# 6.96

# %%
Dataset['cgpa'].mode()
# Out:
# 0    6.67
# 1    7.09
# 2    7.19
# 3    7.33
# 4    7.46
# Name: cgpa, dtype: float64

# %%
sns.distplot(Dataset['placement_exam_marks'])
# Out:
# <ipython-input-8-9a5d8d848435>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Dataset['placement_exam_marks'])
# <Axes: xlabel='placement_exam_marks', ylabel='Density'>

# %%
Dataset['placement_exam_marks'].mean()
# Out:
# 32.225

# %% [markdown]
# **if a column follows Normal distributions it means most of the data points are close to the mean value of that column**

# %%
import numpy as np

# %%
arr1 = np.array([1, 2, 3, 4, 5])
arr1.mean()
# Out:
# 3.0

# %%
arr1.std()
# Out:
# 1.4142135623730951

# %%
# create the normal distribution of Dataset with help of for loop
for i in Dataset.columns:
  sns.displot(Dataset[i], kde=True)
