# %% [markdown]
# ### Import the required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Preparation

# %%
from sklearn import datasets

diabetes_dict = datasets.load_diabetes()

# %%
inp = pd.DataFrame(diabetes_dict.data, columns = diabetes_dict.feature_names)
out = pd.DataFrame(diabetes_dict.target, columns = ['Diabetic'])

df = pd.DataFrame(pd.concat([inp,out], axis = 1))

# %%
df.head(3)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
#
#          s4        s5        s6  Diabetic
# 0 -0.002592  0.019907 -0.017646     151.0
# 1 -0.039493 -0.068332 -0.092204      75.0
# 2 -0.002592  0.002861 -0.025930     141.0

# %% [markdown]
# ### train_test_split

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Diabetic', axis = 1)
y = df['Diabetic']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42, test_size = 0.30)

# %% [markdown]
# ### DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Descision Tree Plot

# %%
# %%time
plt.figure(figsize=(10,10))
plot_tree(dtr,filled=True)
plt.show()
# Out:
# Wall time: 18.4 s
